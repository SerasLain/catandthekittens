# %%
import nltk

from sklearn.utils import shuffle

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import LSTM, TimeDistributed, Bidirectional
from keras.models import Sequential
from keras.layers import Dense, Activation, Embedding, Flatten, Dropout
from keras.utils import to_categorical

import numpy as np
from numpy import array
# Out:
# Using TensorFlow backend.

# %%
import re

# %%
corp = open('/media/sf_communalflat/ihatelinguistics/history.conll', encoding='utf-8').read()

from conllu import parse, parse_tree
from conllu import print_tree

tree = parse(corp)

import re
p = re.compile('[а-яА-ЯёЁ]')
p1=re.compile('[0-9]')

lemmas=[]
for i in tree:
    for j in i:
        if p.search(j['lemma']) and not p1.search(j['lemma']):
            lemmas.append(j['lemma'].lower())

# %%
from numpy import array

def generate_seq(model, tokenizer, max_length, seed_text, n_words):
    in_text = seed_text
    for _ in range(n_words):
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
        yhat = model.predict_classes(encoded, verbose=0)
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
        in_text += ' ' + out_word
    return in_text

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([' '.join(i for i in lemmas)])
encoded = tokenizer.texts_to_sequences([' '.join(i for i in lemmas)])[0]
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
sequences = list()
for i in range(2, len(encoded)):
    sequence = encoded[i-2:i+1]
    sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
sequences = array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)
model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_length-1))
model.add(LSTM(50))
model.add(Dense(vocab_size, activation='softmax'))
print(model.summary())
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=50, verbose=2)
# Out:
# Vocabulary Size: 8134
# Total Sequences: 64202
# Max Sequence Length: 3
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-64-c345a9207a2f> in <module>()
#      43 sequences = array(sequences)
#      44 X, y = sequences[:,:-1],sequences[:,-1]
# ---> 45 y = to_categorical(y, num_classes=vocab_size)
#      46 # define model
#      47 model = Sequential()
#
# ~/anaconda3/envs/mllecture/lib/python3.5/site-packages/keras/utils/np_utils.py in to_categorical(y, num_classes)
#      22         num_classes = np.max(y) + 1
#      23     n = y.shape[0]
# ---> 24     categorical = np.zeros((n, num_classes))
#      25     categorical[np.arange(n), y] = 1
#      26     return categorical
#
# MemoryError:

# %%
#model.save('lemmas_model.h5')

# %%
from keras.models import load_model
model2=load_model('lemmas_model.h5')

# %%
#так генерируется наиболее вероятное следующеее слово
print(generate_seq(model2, tokenizer, max_length-1, 'взгляд православный', 1))
# Out:
# взгляд православный верующий

# %%
#получаем матрицу вероятностей появления для всех известных модели слов после заданного н-грамма
def get_all_probs(model, tokenizer, max_length, seed_text):
    in_text = seed_text
    encoded = tokenizer.texts_to_sequences([in_text])[0]
    encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
    yhat = model.predict(encoded, verbose=0)
    return yhat

# %%
np.sort(get_all_probs(model2, tokenizer, max_length-1, 'взгляд православный')[0])[-5:]
# Out:
# array([ 0.01513699,  0.01998728,  0.04498252,  0.0994028 ,  0.36261377], dtype=float32)

# %%
np.where(get_all_probs(model2, tokenizer, max_length-1, 'взгляд православный')[0]==0.36261377)[0][0]
# Out:
# 1772

# %%
#генерируем строки на замену

inv_dict = {v: k for k, v in tokenizer.word_index.items()}
from pymystem3 import Mystem
m = Mystem()

small=1e-10
#give it lemmatized strings maybe
def get_trigram(trigram_string):
    suggestions=[]
    #for string in trigram_strings:
    prob=0.0
    bigrams=' '.join(m.lemmatize(i)[0] for i in trigram_string[:-1])
    last_word=m.lemmatize(trigram_string[-1])[0]
    prob_matrix=get_all_probs(model2, tokenizer, max_length-1, bigrams)[0]
    most_probable=np.sort(prob_matrix)[-100:]
    if last_word in tokenizer.word_index.keys():
        prob=prob_matrix[tokenizer.word_index[last_word]]
    else:
        prob=small
    if prob in most_probable:
        #pass if trigram's probability is high
        pass
    else:
        for i in most_probable[-3:]:
            ind=np.where(prob_matrix==i)[0][0]
            suggestions.append(bigrams+' '+inv_dict[ind])
    if suggestions:
        return 'возможно неверная коллокация: {}, варианты замен: {}'.format(trigram_string, suggestions)

# %%
get_trigram(['взгляд', 'православный', 'верующий'])

# %%
tokenizer.word_index['верующий']
# Out:
# 1772

# %%
import json
with open('dict.json','w',encoding='utf-8') as out:
    json.dump(tokenizer.word_index,out)

# %%
t= dict()
with open('dict.json','r',encoding='utf-8') as out:
    t =json.load(out)
print(t)
# Out:
# {'трантин': 6484, 'политизировать': 2917, 'целостность': 7767, 'параметр': 4215, 'отличие': 873, 'цельный': 3385, 'сб': 2691, 'пособник': 6564, 'устраиваться': 2437, 'выражать': 1111, 'поддержка': 300, 'унтер': 3755, 'сам': 245, 'созда': 5617, 'имперский': 1389, 'приграничный': 888, 'кайпанен': 6521, 'вкп': 212, 'дисциплина': 1419, 'десятый': 5008, 'тратить': 7267, 'нежелание': 2716, 'этнограф': 2570, 'монарх': 3506, 'отдаленно': 5982, 'нансеновский': 6832, 'надпись': 3082, 'разум': 3226, 'почти': 640, 'память': 2121, 'петерсонс': 5926, 'эхнатен': 4930, 'пе': 4841, 'ректор': 3396, 'звучание': 4048, 'дуга': 6270, 'александровна': 4431, 'обильно': 5131, 'многочисленный': 775, 'ест': 7589, 'дипломированный': 7567, 'сотрудничать': 1522, 'путь': 455, 'решительный': 1991, 'выдвигать': 2132, 'численность': 753, 'рассказ': 1937, 'англо': 2977, 'лень': 6247, 'замечательный': 5179, 'карело': 6283, 'доктор': 818, 'потребность': 3462, 'самоутверждение': 5229, 'наследование': 5503, 'проводиться': 1026, 'знаменитый': 942, 'ниренштейн': 109, 'сильверсван': 7090, 'подписание': 3816, 'оборонительный': 2203, 'ильич': 3911, 'новому': 2396, 'консолидация': 7246, 'дезорганизация': 6295, 'медленно': 3753, 'подробно': 906, 'орудие': 1641, 'судить': 1225, 'риторический': 5201, 'рр': 6806, 'тайлова': 4450, 'брошюра': 3217, 'сектор': 2304, 'оренбург': 7893, 'фундаментально': 4684, 'ярослав': 5461, 'фингерлос': 4803, 'фокусироваться': 4736, 'властный': 2806, 'равнина': 7766, 'через': 621, 'куратор': 3277, 'чуждый': 2459, 'приходиться': 402, 'эрих': 7063, 'уже': 136, 'завод': 1658, 'семиотика': 3305, 'собеседник': 4935, 'доподлинно': 7458, 'показывать': 348, 'ровно': 3617, 'союзный': 1069, 'топ': 6900, 'свирский': 6510, 'финн': 535, 'хлынуть': 6738, 'готовый': 1027, 'буковый': 5753, 'федеративный': 4743, 'отсутствие': 882, 'триумф': 4849, 'склонный': 2660, 'фунт': 2349, 'первоначальный': 5099, 'нога': 6342, 'зарубежный': 960, 'донский': 7385, 'клейст': 5710, 'боеспособность': 2726, 'положительно': 7577, 'распад': 4589, 'ван': 5064, 'выявление': 7014, 'овладевать': 2441, 'академия': 1377, 'колотовкин': 7592, 'простуживаться': 4960, 'полузапрещенный': 7334, 'шаскольский': 5262, 'лагерь': 1461, 'расти': 1768, 'пафнутьич': 8001, 'своему': 3558, 'норт': 4573, 'тезис': 1594, 'проповедь': 3159, 'нацеливать': 2382, 'доверительный': 4681, 'выпуск': 1040, 'необоснованно': 6715, 'салон': 7997, 'командный': 890, 'естественный': 7125, 'одиночку': 5594, 'слагать': 3616, 'становиться': 66, 'командирский': 5645, 'канский': 4557, 'оформлять': 2021, 'сходить': 7550, 'иностранный': 856, 'микроисторический': 1973, 'развертывать': 2797, 'главное': 3659, 'озеро': 2857, 'дезертир': 5927, 'наглядно': 3771, 'ведлозерский': 6530, 'климатический': 6405, 'ооо': 2871, 'политработник': 2232, 'трагический': 2128, 'пропадать': 1666, 'завоеватель': 3482, 'явный': 2788, 'пазон': 4945, 'складываться': 799, 'деблокирование': 6208, 'непреклонный': 7299, 'восточнославянский': 3368, 'враг': 330, 'матчасть': 6014, 'воспитывать': 5480, 'страх': 1131, 'языкознание': 1801, 'де': 867, 'моральный': 2665, 'полупринудительный': 4320, 'ст': 1129, 'карасубазарский': 6645, 'турция': 7236, 'десантный': 6695, 'пехконен': 3907, 'писать': 205, 'близ': 5967, 'дата': 426, 'подлежать': 3664, 'мораль': 5290, 'возрождение': 958, 'испытывать': 1209, 'торф': 6145, 'оккупационный': 1305, 'рокоссовский': 2744, 'обогащать': 8025, 'парус': 6502, 'безопасность': 1294, 'допрос': 3136, 'похоронить': 2463, 'буржуазный': 6019, 'привлекаться': 6333, 'лечебный': 6178, 'полуостров': 1067, 'ду': 5243, 'взвод': 3620, 'коллаборационизм': 1073, 'ву': 4291, 'несомненно': 2684, 'протестантский': 1014, 'блокадный': 6030, 'заведующий': 1734, 'разумеется': 4058, 'секция': 4191, 'чтоб': 6707, 'обладатель': 7503, 'въезжать': 3023, 'королевство': 2098, 'сначала': 2061, 'командование': 228, 'путешествие': 7875, 'четверо': 3669, 'заплатить': 7539, 'зарплата': 2835, 'ахиллесов': 7238, 'иметь': 165, 'саксония': 4818, 'научаться': 4602, 'поло ...

# %%
#тестируем
test=open('бэд.txt', encoding='utf-8').read()

# %%
import nltk
from nltk.util import ngrams

# %%
clean_text=[]
for i in test.split():
    i=i.lower()
    if p.search(i) and not p1.search(i):
        clean_text.append(i)

# %%
trigrams=list(ngrams(clean_text,3))

# %%
for i in range(15):
    print(get_trigram(list(trigrams[i])))
# Out:
# возможно неверная коллокация: ['введение', 'особое', 'значение'], варианты замен: ['введение особый два', 'введение особый политический', 'введение особый прорыв']
# возможно неверная коллокация: ['особое', 'значение', 'приобретает'], варианты замен: ['особый значение русский', 'особый значение в', 'особый значение по']
# возможно неверная коллокация: ['значение', 'приобретает', 'вопрос'], варианты замен: ['значение приобретать главный', 'значение приобретать этот', 'значение приобретать что']
# None
# возможно неверная коллокация: ['вопрос', 'о', 'заговоре'], варианты замен: ['вопрос о сохранность', 'вопрос о статус', 'вопрос о то']
# возможно неверная коллокация: ['о', 'заговоре', 'против'], варианты замен: ['о заговор стрелковый', 'о заговор наркомат', 'о заговор противник']
# возможно неверная коллокация: ['заговоре', 'против', 'павла'], варианты замен: ['заговор против рф', 'заговор против район', 'заговор против былой']
# возможно неверная коллокация: ['против', 'павла', 'император'], варианты замен: ['против павел причина', 'против павел шифр', 'против павел выполнение']
# возможно неверная коллокация: ['павла', 'император', 'всероссийский'], варианты замен: ['павел император будто', 'павел император наркомат', 'павел император михаил']
# возможно неверная коллокация: ['император', 'всероссийский', 'умер'], варианты замен: ['император всероссийский обмундирование', 'император всероссийский авиация', 'император всероссийский чуб']
# возможно неверная коллокация: ['всероссийский', 'умер', 'уже'], варианты замен: ['всероссийский умирать до', 'всероссийский умирать якобсон', 'всероссийский умирать в']
# возможно неверная коллокация: ['умер', 'уже', 'раскрытой'], варианты замен: ['умирать уже по', 'умирать уже на', 'умирать уже в']
# возможно неверная коллокация: ['уже', 'раскрытой', 'смертью,'], варианты замен: ['уже раскрывать известный', 'уже раскрывать победа', 'уже раскрывать же']
# None
# возможно неверная коллокация: ['смертью,', 'но', 'хотелось'], варианты замен: ['смерть но об', 'смерть но на', 'смерть но сын']
